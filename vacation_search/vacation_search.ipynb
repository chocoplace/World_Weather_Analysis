# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv(r"C:\Users\mhern\Desktop\Analysis_Projects_2021\Module_6\World_Weather_Analysis\weather_database\WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0       Rikitea      PF -23.1203 -134.9692     73.85        58
# 1        1  Puerto Ayora      EC  -0.7393  -90.3518     69.04        83
# 2        2     Dovolnoye      RU  54.4958   79.6671     14.99        83
# 3        3       Ushuaia      AR -54.8000  -68.3000     33.46        93
# 4        4        Hasaki      JP  35.7333  140.8333     63.28        57
#
#    Cloudiness  Wind Speed Current Description
# 0          19        3.42          few clouds
# 1          72        8.01       broken clouds
# 2         100       12.57     overcast clouds
# 3          75       25.32          light snow
# 4          96        5.70     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df= city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID              City Country      Lat       Lng  Max Temp  Humidity  \
# 5         5           Cayenne      GF   4.9333  -52.3333     80.10        88
# 11       11       Grand Gaube      MU -20.0064   57.6608     79.38        70
# 12       12             Vaini      TO -21.2000 -175.2000     82.56        89
# 13       13         Mahebourg      MU -20.4081   57.7000     79.25        69
# 16       16            Alugan      PH  12.2188  125.4808     84.51        74
# 21       21           Ambunti      PG  -4.2365  142.8448     88.38        66
# 26       26  Puerto Escondido      MX  15.8500  -97.0667     78.51        78
# 27       27           Isangel      VU -19.5500  169.2667     79.68        70
# 28       28            Atuona      PF  -9.8000 -139.0333     78.51        75
# 31       31          Lorengau      PG  -2.0226  147.2712     85.68        62
#
#     Cloudiness  Wind Speed      Current Description
# 5           20        0.00               few clouds
# 11          14       11.01               light rain
# 12          75        6.91  light intensity drizzle
# 13          24       10.67               light rain
# 16          48        6.67         scattered clouds
# 21          57        1.54            broken clouds
# 26           0        4.74                clear sky
# 27         100        7.72          overcast clouds
# 28           9       12.59                clear sky
# 31          25        5.46         scattered clouds

# %%
# 4a. Determine if there are any empty rows.
print(len(preferred_cities_df))
# Out:
# 176

# %%
preferred_cities_df.count
# Out:
# <bound method DataFrame.count of      City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 5          5      Cayenne      GF   4.9333  -52.3333     80.10        88
# 11        11  Grand Gaube      MU -20.0064   57.6608     79.38        70
# 12        12        Vaini      TO -21.2000 -175.2000     82.56        89
# 13        13    Mahebourg      MU -20.4081   57.7000     79.25        69
# 16        16       Alugan      PH  12.2188  125.4808     84.51        74
# ..       ...          ...     ...      ...       ...       ...       ...
# 660      660      Bintulu      MY   3.1667  113.0333     86.41        79
# 671      671         Gizo      SB  -8.1030  156.8419     85.05        63
# 674      674     Lufilufi      WS -13.8745 -171.5986     78.58        73
# 680      680    Canchungo      GW  12.0672  -16.0333     75.33        80
# 683      683  Keti Bandar      PK  24.1447   67.4497     77.20        20
#
#      Cloudiness  Wind Speed      Current Description
# 5            20        0.00               few clouds
# 11           14       11.01               light rain
# 12           75        6.91  light intensity drizzle
# 13           24       10.67               light rain
# 16           48        6.67         scattered clouds
# ..          ...         ...                      ...
# 660          20        4.61               few clouds
# 671          11        4.34               few clouds
# 674           9       14.67                clear sky
# 680           8        3.69                clear sky
# 683           0       20.29                clear sky
#
# [176 rows x 10 columns]>

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
preferred_cities_df.count()
# Out:
# City_ID                176
# City                   176
# Country                176
# Lat                    176
# Lng                    176
# Max Temp               176
# Humidity               176
# Cloudiness             176
# Wind Speed             176
# Current Description    176
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna(axis="index", how="any")
print(len(clean_df))
# Out:
# 176

# %%
clean_df.head()
# Out:
#     City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 5         5      Cayenne      GF   4.9333  -52.3333     80.10        88
# 11       11  Grand Gaube      MU -20.0064   57.6608     79.38        70
# 12       12        Vaini      TO -21.2000 -175.2000     82.56        89
# 13       13    Mahebourg      MU -20.4081   57.7000     79.25        69
# 16       16       Alugan      PH  12.2188  125.4808     84.51        74
#
#     Cloudiness  Wind Speed      Current Description
# 5           20        0.00               few clouds
# 11          14       11.01               light rain
# 12          75        6.91  light intensity drizzle
# 13          24       10.67               light rain
# 16          48        6.67         scattered clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp      Current Description      Lat  \
# 5            Cayenne      GF     80.10               few clouds   4.9333
# 11       Grand Gaube      MU     79.38               light rain -20.0064
# 12             Vaini      TO     82.56  light intensity drizzle -21.2000
# 13         Mahebourg      MU     79.25               light rain -20.4081
# 16            Alugan      PH     84.51         scattered clouds  12.2188
# 21           Ambunti      PG     88.38            broken clouds  -4.2365
# 26  Puerto Escondido      MX     78.51                clear sky  15.8500
# 27           Isangel      VU     79.68          overcast clouds -19.5500
# 28            Atuona      PF     78.51                clear sky  -9.8000
# 31          Lorengau      PG     85.68         scattered clouds  -2.0226
#
#          Lng Hotel Name
# 5   -52.3333
# 11   57.6608
# 12 -175.2000
# 13   57.7000
# 16  125.4808
# 21  142.8448
# 26  -97.0667
# 27  169.2667
# 28 -139.0333
# 31  147.2712

# %%
len(hotel_df)
# Out:
# 176

# %%
# 6a. Set parameters to search for hotels with 5000 meters.    
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna(axis="index", how="any")
clean_hotel_df.head(10)
# Out:
#                 City Country  Max Temp      Current Description      Lat  \
# 5            Cayenne      GF     80.10               few clouds   4.9333
# 11       Grand Gaube      MU     79.38               light rain -20.0064
# 12             Vaini      TO     82.56  light intensity drizzle -21.2000
# 13         Mahebourg      MU     79.25               light rain -20.4081
# 16            Alugan      PH     84.51         scattered clouds  12.2188
# 21           Ambunti      PG     88.38            broken clouds  -4.2365
# 26  Puerto Escondido      MX     78.51                clear sky  15.8500
# 27           Isangel      VU     79.68          overcast clouds -19.5500
# 28            Atuona      PF     78.51                clear sky  -9.8000
# 31          Lorengau      PG     85.68         scattered clouds  -2.0226
#
#          Lng                            Hotel Name
# 5   -52.3333                       Hôtel Le Dronmi
# 11   57.6608  Veranda Paul et Virginie Hotel & Spa
# 12 -175.2000                   Keleti Beach Resort
# 13   57.7000    Shandrani Beachcomber Resort & Spa
# 16  125.4808                              JM Lodge
# 21  142.8448                         Ambunti Lodge
# 26  -97.0667         Aldea del Bazar Hotel and Spa
# 27  169.2667                           Tanna Lodge
# 28 -139.0333                           Villa Enata
# 31  147.2712            Lorengau Harbourside Hotel

# %%
# 8a. Create the output File (CSV)
output_data_file = "C:/Users/mhern/Desktop/Analysis_Projects_2021/Module_6/World_Weather_Analysis/vacation_search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
